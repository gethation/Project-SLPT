# %% [markdown]
# # import

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
! pip install lightly
! pip install wandb

# %%
import shutil
import os
def copyfile(file_list, folder=''):
  for file in file_list:
    shutil.copyfile(file, os.path.join(folder,os.path.basename(file)))

list_py = ['/content/gdrive/Othercomputers/我的筆記型電腦/google drive/MAE Bs PJ/model.py',
      '/content/gdrive/Othercomputers/我的筆記型電腦/google drive/MAE Bs PJ/utils.py',
      '/content/gdrive/Othercomputers/我的筆記型電腦/google drive/MAE Bs PJ/dataset.zip',
      '/content/gdrive/Othercomputers/我的筆記型電腦/google drive/MAE Bs PJ/masked_autoencoder.py']

copyfile(list_py)

# %%
from utils import extract_and_split

data_folder = 'dataset/dataset'
test_folder = 'test_set/test_set'
extract_and_split(zip_file_path = 'dataset.zip',
         extract_folder = 'dataset',
         test_folder = test_folder,
         data_folder = data_folder,
         ratio = 0.1)

# %%
import torch
import torchvision
from torch import nn

from lightly.models import utils
import masked_autoencoder
from lightly.transforms.mae_transform import MAETransform
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset

from model import MAE
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
from IPython.display import Video
from tqdm.auto import tqdm, trange
from utils import MPJPELoss

# %% [markdown]
# # model

# %%
point_num = 90

vit = torchvision.models.vit_b_16(weights=None)
model = MAE(vit=vit,
            seq_length=64,
            out_dim=point_num)

device = "cuda"
model.to(device)

learning_rate = 1e-6
batch_size = 4 #alter
Epochs = 10

criterion = MPJPELoss(point_num=point_num)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

# %% [markdown]
# # wandb set

# %%
import wandb
from utils import normalize_data, Node_Dataset, load_mean_std, get_time
CHECKPOINT_PATH = '/content/gdrive/Othercomputers/我的筆記型電腦/google drive/MAE Bs PJ/state_dict/checkpoint.tar'
model_savepath = f'/content/gdrive/Othercomputers/我的筆記型電腦/google drive/MAE Bs PJ/state_dict'

mean, std = load_mean_std(data_folder)

wandb.init(
    project='MaE bs PJ',
    name=f'batch_size: {batch_size}',
    config={
        "learning_rate": learning_rate,
        "architecture": "ViT",
        "dataset": "customer",
        "epochs": Epochs,
        "mean": mean,
        "std": std},
    resume=True)
config = wandb.config

wandb.watch(model)
epoch = 0
step = 0
total_loss = 0

# %%
# if True:
#     copyfile([CHECKPOINT_PATH])
#     checkpoint = torch.load(os.path.basename(CHECKPOINT_PATH))
#     model.load_state_dict(checkpoint['model_state_dict'])
#     optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#     step = checkpoint['step']
#     mean = checkpoint['mean']
#     std = checkpoint['std']

# %%
# model.load_state_dict(torch.load('/content/gdrive/Othercomputers/我的筆記型電腦/google drive/MAE Bs PJ/state_dict/epoch:1-3300:weight.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # data

# %%
from torchvision import transforms
from utils import normalize_data, Node_Dataset, load_mean_std, get_time
from torch.utils.data import DataLoader, Dataset

# %%
data_folder = 'dataset/dataset'
test_folder = 'test_set/test_set'
batch_size = 4

dataset = Node_Dataset(data_folder, mean, std)
trainloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

test_dataset = Node_Dataset(test_folder, mean, std)
testloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
print(mean, std)
# Out:
# 331.4973449707031 130.28567504882812

# %%
from utils import video_show, train_step, Evaluate, log

# %% [markdown]
# # train

# %%
for epoch in range(Epochs):
    for i, batch in tqdm(enumerate(trainloader), total=len(trainloader)):

        loss = train_step(model,
                criterion,
                batch,
                optimizer)
        total_loss += loss

        if (i+1)%100 == 0:
            with torch.no_grad():
                evaluate_loss, visual_prediction, visual_target = Evaluate(model, criterion, testloader)

            log(CHECKPOINT_PATH, model, optimizer, step, mean, std)
            torch.save(model.state_dict(),os.path.join(model_savepath, f'epoch:{epoch}-{i+1}:weight.pt'))
            video = video_show(visual_prediction, visual_target, mean, std,'/content/output.mp4')
            wandb.log({"train_loss": total_loss,"test_loss": evaluate_loss, "visulize": wandb.Video(video, fps=5)}, step=step)
            step += 1
            total_loss = 0

    print(f'epoch: {epoch:>02}, time: {get_time()}')
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# epoch: 00, time: 24:17:49
#   0%|          | 0/11 [00:00<?, ?it/s]
# epoch: 01, time: 24:17:53
#   0%|          | 0/11 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2016\871953440.py in <module>
#       1 for epoch in range(Epochs):
# ----> 2     for i, batch in tqdm(enumerate(trainloader), total=len(trainloader)):
#       3
#       4         loss = train_step(model,
#       5                 criterion,
#
# c:\Users\Huang\anaconda3\lib\site-packages\tqdm\notebook.py in __iter__(self)
#     248         try:
#     249             it = super().__iter__()
# --> 250             for obj in it:
#     251                 # return super(tqdm...) will not catch exception
#     252                 yield obj
#
# c:\Users\Huang\anaconda3\lib\site-packages\tqdm\std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# c:\Users\Huang\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# c:\Users\Huang\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# c:\Users\Huang\anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# c:\Users\Huang\anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# d:\Project-SEKAI\Project-SEKAI\MAE Bs PJ\utils.py in __getitem__(self, idx)
#     162             x = json.load(file)
#     163
# --> 164         data = self.Augmentor.augment(x)
#     165         data = torch.as_tensor(torch.from_numpy(data), dtype=torch.float32)
#     166         batch = normalize_data(data, self.mean, self.std)
#
# d:\Project-SEKAI\Project-SEKAI\MAE Bs PJ\utils.py in augment(self, x)
#     245         coordinates = self.random_split(coordinates)
#     246         coordinates = self.random_rotate(coordinates)
# --> 247         coordinates = self.random_scaling(coordinates)
#     248         coordinates = self.offsetalize(coordinates)
#     249         return coordinates
#
# d:\Project-SEKAI\Project-SEKAI\MAE Bs PJ\utils.py in random_scaling(self, coordinates)
#     231         for i, frame in enumerate(coordinates):
#     232             for j, point in enumerate(frame):
# --> 233                 scaled_coordinates[i, j] = self.scaling_point(point)
#     234         return scaled_coordinates
#     235
#
# d:\Project-SEKAI\Project-SEKAI\MAE Bs PJ\utils.py in scaling_point(self, point)
#     215
#     216     def scaling_point(self, point):
# --> 217         offset = point - self.center
#     218         scaled_offset = offset * self.scale_factor
#     219         scaled_point = scaled_offset + self.center
#
# KeyboardInterrupt:
